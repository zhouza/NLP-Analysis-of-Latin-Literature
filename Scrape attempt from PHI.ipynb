# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Sun Oct 15 19:31:48 2017
@author: sjhuskey
"""

''' This script:
        * reads in the data at http://latin.packhum.org/canon (the PHI canon).
        * scrapes data for each work.
        * writes results to a CSV file
    See inline comments for information about how it works.
    
    Parts of this program owe much to Lisa Tagliaferri's tutorial at https://www.digitalocean.com/community/tutorials/how-to-scrape-web-pages-with-beautiful-soup-and-python-3.
    Tyler Pearson, Director of Informatics for OU Libraries, provided advice and support.
'''
    
import requests, csv, codecs
from bs4 import BeautifulSoup

# Create the CSV file, open it so that it appends new data instead of overwriting old data.
with codecs.open('data/phi.csv','w',encoding='utf8') as f:
    w = csv.writer(f)

# Write the header for the CSV.
    w.writerow(['Author','PHI Author Number','Title','PHI Work Number','Combined PHI Number','Reference Edition','URL','Publisher','Rights'])

# Open the page and parse the data.
    page = requests.get('http://latin.packhum.org/canon')
    soup = BeautifulSoup(page.text, 'lxml')
        
# Limit the html to just the main content of the page.
    item_list = soup.find('div', class_="canon")

    '''Since author name data is in a different level of the tree from the works,
    create a dictionary with author number as key and author name as value.
    Since the works also include the author number, the dictionary will be 
    a lookup table for when the data is assembled into rows for the CSV below.'''

# Select the author numbers, being sure to select from the author level, not the work level.        
    anums1 = item_list.select('a[class="alnk"] > span[class="anum"]')

# Make an empty list to hold the author numbers as they're generated.
    number_list = []

# Loop through the anums and use .text to get just the numbers. Use .append
# to add them to the number_list.
    for anum in anums1:
        numbers = anum.text
        number_list.append(numbers)

# Select the spans with class "anam", which contains the author's name.
    anams = item_list.find_all('span', {'class' : 'anam'})

# Make an empty list to hold the author names as they're generated.    
    author_list = []

# Loop through the anams and use .text to get just the text for the names. Use
# .append to add the authors to the author_list.
    for anam in anams:
        authors = anam.span.text
        author_list.append(authors)

# Make the dictionary with number as key and name as value for each author.        
    author_dict = dict(zip(number_list,author_list))   
    
# Now, select the data for the works.
    
# Author numbers, which will be used for the lookup below.    
    anums2 = item_list.select('a[class="wlnk"] > span[class="anum"]')
# Work names.
    wnams = item_list.select('span[class="wnam"] > span')
# Work numbers.
    wnums = item_list.select('span[class="wnum"]')
# Bibliography for the reference edition.
    bib_list = item_list.find_all('span', {'class' : 'bib'})
# Relative link to the work.
    link_list = item_list.select('li[class="work"] > a')

# Create an empty list to hold numbers as they're generated below.
    lookup_keys = []
# Loop through of author numbers to and append them to the lookup_keys list. 
    for anumber in anums2:
        author_numbers = anumber.text
        lookup_keys.append(author_numbers)

# Create an empty list to hold values as they're retrieved from the author_dict.
    lookup_values = []
# Loop through the lookup_keys list and retrieve the corresponding values from author_dict.
    for item in lookup_keys:
        if item in author_dict:
            lookup_values.append(author_dict.get(item))
    
# Put all of the data together.
    for author, anum, wnam, wnum, bib, link in zip(lookup_values, anums2, wnams, wnums, bib_list, link_list):            
        anums = anum.contents[0]
        works = wnam.text
        work_numbers = wnum.contents[0]
        phi_number = anums + '.' + work_numbers      
        bibs = bib.text
        links = 'http://latin.packhum.org' + link['href']
        publisher = "PHI"
        rights = "Fair Use"

# Write results to the CSV file.                
        w.writerow([author,anums,works,work_numbers,phi_number,bibs,links,publisher,rights])

# %%
author_df = pd.read_csv('data/phi.csv',sep=',')

# %%
author_df
# Out:
#                            Author  PHI Author Number  \
# 0                        Ablabius               2000
# 1                   Lucius Accius                400
# 2                   Lucius Accius                400
# 3                   Lucius Accius                400
# 4               Valerius Aedituus                402
# 5                   Aemilius Sura               2300
# 6                 Lucius Afranius                404
# 7                Iulius Africanus                902
# 8     Gnaeus Domitius Ahenobarbus                301
# 9                  Albinus, poet.               2002
# 10                 Albinus, poet.               2002
# 11          Publius Alfenus Varus                406
# 12   Altercatio Hadr. et Epicteti               1500
# 13                Lucius Ampelius               1206
# 14       Lucius Livius Andronicus                 94
# 15       Lucius Livius Andronicus                 94
# 16       Lucius Livius Andronicus                 94
# 17                       Annianus               1209
# 18            Titus Annius Luscus                  2
# 19        Anonymi Epici et Lyrici               9500
# 20        Anonymi Epici et Lyrici               9500
# 21        Anonymi Epici et Lyrici               9500
# 22        Anonymi Epici et Lyrici               9500
# 23        Anonymi Epici et Lyrici               9500
# 24        Anonymi Epici et Lyrici               9500
# 25        Anonymi Epici et Lyrici               9500
# 26        Anonymi Epici et Lyrici               9500
# 27        Anonymi Epici et Lyrici               9500
# 28        Anonymi Epici et Lyrici               9500
# 29        Anonymi Epici et Lyrici               9500
# ..                            ...                ...
# 806                  Pseudo-Varro               1041
# 807                 Velius Longus               1374
# 808           Velleius Paterculus               1044
# 809                      Veranius               1047
# 810           Appendix Vergiliana                692
# 811           Appendix Vergiliana                692
# 812           Appendix Vergiliana                692
# 813           Appendix Vergiliana                692
# 814           Appendix Vergiliana                692
# 815           Appendix Vergiliana                692
# 816           Appendix Vergiliana                692
# 817           Appendix Vergiliana                692
# 818           Appendix Vergiliana                692
# 819           Appendix Vergiliana                692
# 820           Appendix Vergiliana                692
# 821           Appendix Vergiliana                692
# 822           Appendix Vergiliana                692
# 823           Appendix Vergiliana                692
# 824        Publius Vergilius Maro                690
# 825        Publius Vergilius Maro                690
# 826        Publius Vergilius Maro                690
# 827        Lucius Verginius Rufus               1050
# 828        Marcus Verrius Flaccus                869
# 829        Marcus Verrius Flaccus                869
# 830                Vibius Crispus               1053
# 831                Vita Iuvenalis               9969
# 832                     Vitruvius               1056
# 833           Volcacius Sedigitus                330
# 834                     Volumnius                694
# 835                Zeno of Verona               2150
#
#                                      Title  PHI Work Number  \
# 0                                epigramma                1
# 1                                  carmina                1
# 2                               praetextae                2
# 3                               tragoediae                3
# 4                              epigrammata                1
# 5                   De Annis Populi Romani                1
# 6                                  togatae                1
# 7                                   oratio                1
# 8                                   oratio                1
# 9                  Rerum Romanarum Liber I                1
# 10                               De Metris                2
# 11               iurisprudentia, fragmenta                2
# 12            Altercatio Hadr. et Epicteti                1
# 13                        Liber Memorialis                1
# 14                                 Odyssia                1
# 15                              tragoediae                2
# 16                               palliatae                3
# 17                                 carmina                1
# 18                                  oratio                1
# 19                          carmen Saliare                1
# 20                         versus sacrorum                2
# 21                               sententia                3
# 22              A. Atilii Calatini elogium                4
# 23                           carmen Priami                5
# 24                            saturnius(?)                6
# 25                Acilii Glabrionis tabula                7
# 26           M. Aemilii cos. a. 179 tabula                8
# 27         versiculi populares et pueriles                9
# 28             praecepta rustica et medica               10
# 29   epigramma a Varrone Plauto attributum               11
# ..                                     ...              ...
# 806                             Sententiae                1
# 807                        De Orthographia                1
# 808                        Historia Romana                1
# 809                  libri de rebus sacris                1
# 810                                  Dirae                1
# 811                                  Lydia                2
# 812                                  Culex                3
# 813                                  Aetna                4
# 814                                   Copa                5
# 815                  Elegiae in Maecenatem                6
# 816                                  Ciris                7
# 817                                Priapea                8
# 818                             Catalepton                9
# 819          Priapeum 'Quid Hoc Novi Est?'               10
# 820                                Moretum               11
# 821              De Institutione Viri Boni               12
# 822                          De Est et Non               13
# 823                   De Rosis Nascentibus               14
# 824                                Eclogae                1
# 825                               Georgica                2
# 826                                 Aeneis                3
# 827                              epigramma                1
# 828                 Etruscarum Rerum Libri                1
# 829                             grammatica                2
# 830                              orationes                1
# 831                         Vita Iuvenalis                1
# 832                        De Architectura                1
# 833                                carmina                1
# 834                                 carmen                1
# 835                              Tractatus                1
#
#      Combined PHI Number                                  Reference Edition  \
# 0               2000.001  Fragmenta Poetarum Latinorum Epicorum et Lyric...
# 1                400.001  Fragmenta Poetarum Latinorum Epicorum et Lyric...
# 2                400.002  Scaenicae Romanorum Poesis Fragmenta. Vol. 1, ...
# 3                400.003  Scaenicae Romanorum Poesis Fragmenta. Vol. 1, ...
# 4                402.001  Fragmenta Poetarum Latinorum Epicorum et Lyric...
# 5               2300.001  Historicorum Romanorum Reliquiae, Vol. 2, ed. ...
# 6                404.001  Scaenicae Romanorum Poesis Fragmenta. Vol. 2, ...
# 7                902.001  M. Fabi Quintiliani Institutionis Oratoriae Li...
# 8                301.001  Oratorum Romanorum Fragmenta Liberae Rei Publi...
# 9               2002.001  Fragmenta Poetarum Latinorum Epicorum et Lyric...
# 10              2002.002  Fragmenta Poetarum Latinorum Epicorum et Lyric...
# 11               406.002  Iurisprudentiae Anteiustinianae Reliquiae. Vol...
# 12              1500.001  Altercatio Hadriani Augusti et Epicteti Philos...
# 13              1206.001  Lucii Ampelii Liber Memorialis, ed. E. Assmann...
# 14                94.001  Fragmenta Poetarum Latinorum Epicorum et Lyric...
# 15                94.002  Scaenicae Romanorum Poesis Fragmenta. Vol. 1, ...
# 16                94.003  Scaenicae Romanorum Poesis Fragmenta. Vol. 2, ...
# 17              1209.001  Fragmenta Poetarum Latinorum Epicorum et Lyric...
# 18                 2.001  Oratorum Romanorum Fragmenta Liberae Rei Publi...
# 19              9500.001  Fragmenta Poetarum Latinorum Epicorum et Lyric...
# 20              9500.002  Fragmenta Poetarum Latinorum Epicorum et Lyric...
# 21              9500.003  Fragmenta Poetarum Latinorum Epicorum et Lyric...
# 22              9500.004  Fragmenta Poetarum Latinorum Epicorum et Lyric...
# 23              9500.005  Fragmenta Poetarum Latinorum Epicorum et Lyric...
# 24              9500.006  ?) Fragmenta Poetarum Latinorum Epicorum et Ly...
# 25              9500.007  Fragmenta Poetarum Latinorum Epicorum et Lyric...
# 26              9500.008  Fragmenta Poetarum Latinorum Epicorum et Lyric...
# 27              9500.009  Fragmenta Poetarum Latinorum Epicorum et Lyric...
# 28              9500.010  Fragmenta Poetarum Latinorum Epicorum et Lyric...
# 29              9500.011  Fragmenta Poetarum Latinorum Epicorum et Lyric...
# ..                   ...                                                ...
# 806             1041.001  Die sogenannten Sententiae Varronis, ed. P. Ge...
# 807             1374.001  Grammatici Latini ex Recensione Henrici Keilii...
# 808             1044.001  Velleius Paterculus: Histoire Romaine. Vols. 1...
# 809             1047.001  Iurisprudentiae Anteiustinianae Reliquiae. Vol...
# 810              692.001        Appendix Vergiliana, ed. E. J. Kenney, 1966
# 811              692.002        Appendix Vergiliana, ed. E. J. Kenney, 1966
# 812              692.003       Appendix Vergiliana, ed. W. V. Clausen, 1966
# 813              692.004   Appendix Vergiliana, ed. F. R. D. Goodyear, 1966
# 814              692.005        Appendix Vergiliana, ed. E. J. Kenney, 1966
# 815              692.006        Appendix Vergiliana, ed. E. J. Kenney, 1966
# 816              692.007   Appendix Vergiliana, ed. F. R. D. Goodyear, 1966
# 817              692.008      Appendix Vergiliana, ed. J. A. Richmond, 1966
# 818              692.009      Appendix Vergiliana, ed. J. A. Richmond, 1966
# 819              692.010      Appendix Vergiliana, ed. J. A. Richmond, 1966
# 820              692.011        Appendix Vergiliana, ed. E. J. Kenney, 1966
# 821              692.012       Appendix Vergiliana, ed. W. V. Clausen, 1966
# 822              692.013       Appendix Vergiliana, ed. W. V. Clausen, 1966
# 823              692.014       Appendix Vergiliana, ed. W. V. Clausen, 1966
# 824              690.001  P. Vergili Maronis Opera, ed. R. A. B. Mynors,...
# 825              690.002  P. Vergili Maronis Opera, ed. R. A. B. Mynors,...
# 826              690.003  P. Vergili Maronis Opera, ed. R. A. B. Mynors,...
# 827             1050.001  Fragmenta Poetarum Latinorum Epicorum et Lyric...
# 828              869.001  Historicorum Romanorum Reliquiae. Vol. 2, ed. ...
# 829              869.002  Grammaticae Romanae Fragmenta, ed. G. Funaioli...
# 830             1053.001  M. Fabi Quintiliani Institutionis Oratoriae Li...
# 831             9969.001  A. Persi Flacci et D. Iuni Iuvenalis Saturae, ...
# 832             1056.001       Vitruvii de Architectura, ed. F. Krohn, 1912
# 833              330.001  Fragmenta Poetarum Latinorum Epicorum et Lyric...
# 834              694.001  Fragmenta Poetarum Latinorum Epicorum et Lyric...
# 835             2150.001   Zeno Veronensis Tractatus, ed. B. Löfstedt, 1971
#
#                                         URL Publisher    Rights
# 0     http://latin.packhum.org/loc/2000/1/0       PHI  Fair Use
# 1      http://latin.packhum.org/loc/400/1/0       PHI  Fair Use
# 2      http://latin.packhum.org/loc/400/2/0       PHI  Fair Use
# 3      http://latin.packhum.org/loc/400/3/0       PHI  Fair Use
# 4      http://latin.packhum.org/loc/402/1/0       PHI  Fair Use
# 5     http://latin.packhum.org/loc/2300/1/0       PHI  Fair Use
# 6      http://latin.packhum.org/loc/404/1/0       PHI  Fair Use
# 7      http://latin.packhum.org/loc/902/1/0       PHI  Fair Use
# 8      http://latin.packhum.org/loc/301/1/0       PHI  Fair Use
# 9     http://latin.packhum.org/loc/2002/1/0       PHI  Fair Use
# 10    http://latin.packhum.org/loc/2002/2/0       PHI  Fair Use
# 11     http://latin.packhum.org/loc/406/2/0       PHI  Fair Use
# 12    http://latin.packhum.org/loc/1500/1/0       PHI  Fair Use
# 13    http://latin.packhum.org/loc/1206/1/0       PHI  Fair Use
# 14      http://latin.packhum.org/loc/94/1/0       PHI  Fair Use
# 15      http://latin.packhum.org/loc/94/2/0       PHI  Fair Use
# 16      http://latin.packhum.org/loc/94/3/0       PHI  Fair Use
# 17    http://latin.packhum.org/loc/1209/1/0       PHI  Fair Use
# 18       http://latin.packhum.org/loc/2/1/0       PHI  Fair Use
# 19    http://latin.packhum.org/loc/9500/1/0       PHI  Fair Use
# 20    http://latin.packhum.org/loc/9500/2/0       PHI  Fair Use
# 21    http://latin.packhum.org/loc/9500/3/0       PHI  Fair Use
# 22    http://latin.packhum.org/loc/9500/4/0       PHI  Fair Use
# 23    http://latin.packhum.org/loc/9500/5/0       PHI  Fair Use
# 24    http://latin.packhum.org/loc/9500/6/0       PHI  Fair Use
# 25    http://latin.packhum.org/loc/9500/7/0       PHI  Fair Use
# 26    http://latin.packhum.org/loc/9500/8/0       PHI  Fair Use
# 27    http://latin.packhum.org/loc/9500/9/0       PHI  Fair Use
# 28   http://latin.packhum.org/loc/9500/10/0       PHI  Fair Use
# 29   http://latin.packhum.org/loc/9500/11/0       PHI  Fair Use
# ..                                      ...       ...       ...
# 806   http://latin.packhum.org/loc/1041/1/0       PHI  Fair Use
# 807   http://latin.packhum.org/loc/1374/1/0       PHI  Fair Use
# 808   http://latin.packhum.org/loc/1044/1/0       PHI  Fair Use
# 809   http://latin.packhum.org/loc/1047/1/0       PHI  Fair Use
# 810    http://latin.packhum.org/loc/692/1/0       PHI  Fair Use
# 811    http://latin.packhum.org/loc/692/2/0       PHI  Fair Use
# 812    http://latin.packhum.org/loc/692/3/0       PHI  Fair Use
# 813    http://latin.packhum.org/loc/692/4/0       PHI  Fair Use
# 814    http://latin.packhum.org/loc/692/5/0       PHI  Fair Use
# 815    http://latin.packhum.org/loc/692/6/0       PHI  Fair Use
# 816    http://latin.packhum.org/loc/692/7/0       PHI  Fair Use
# 817    http://latin.packhum.org/loc/692/8/0       PHI  Fair Use
# 818    http://latin.packhum.org/loc/692/9/0       PHI  Fair Use
# 819   http://latin.packhum.org/loc/692/10/0       PHI  Fair Use
# 820   http://latin.packhum.org/loc/692/11/0       PHI  Fair Use
# 821   http://latin.packhum.org/loc/692/12/0       PHI  Fair Use
# 822   http://latin.packhum.org/loc/692/13/0       PHI  Fair Use
# 823   http://latin.packhum.org/loc/692/14/0       PHI  Fair Use
# 824    http://latin.packhum.org/loc/690/1/0       PHI  Fair Use
# 825    http://latin.packhum.org/loc/690/2/0       PHI  Fair Use
# 826    http://latin.packhum.org/loc/690/3/0       PHI  Fair Use
# 827   http://latin.packhum.org/loc/1050/1/0       PHI  Fair Use
# 828    http://latin.packhum.org/loc/869/1/0       PHI  Fair Use
# 829    http://latin.packhum.org/loc/869/2/0       PHI  Fair Use
# 830   http://latin.packhum.org/loc/1053/1/0       PHI  Fair Use
# 831   http://latin.packhum.org/loc/9969/1/0       PHI  Fair Use
# 832   http://latin.packhum.org/loc/1056/1/0       PHI  Fair Use
# 833    http://latin.packhum.org/loc/330/1/0       PHI  Fair Use
# 834    http://latin.packhum.org/loc/694/1/0       PHI  Fair Use
# 835   http://latin.packhum.org/loc/2150/1/0       PHI  Fair Use
#
# [836 rows x 9 columns]

# %%
author_df['Author'].value_counts()
# Out:
# Marcus Tullius Cicero                75
# Anonymi Epici et Lyrici              41
# Scriptores Historiae Augustae        30
# Titus Maccius Plautus                22
# Didascaliae et Argum. in Plautum     19
# Lucius Annaeus Seneca iunior         18
# Marcus Terentius Varro               17
# Marcus Cornelius Fronto              17
# Publius Ovidius Naso                 15
# Appendix Vergiliana                  14
# Marcus Porcius Cato                  12
# Apuleius Madaurensis                 10
# Gaius Iulius Caesar                   8
# Fragmenta Bobiensia                   8
# Gaius Sallustius Crispus              8
# C. Iul. Caes. Augustus Octavianus     8
# Gaius Caesius Bassus                  7
# Maurus Servius Honoratus              7
# Gnaeus Naevius                        7
# Quintus Ennius                        7
# Pomponius Porphyrio                   7
# Quintus Horatius Flaccus              6
# Publius Terentius Afer                6
# Gaius Suetonius Tranquillus           6
# Sextus Iulius Frontinus               6
# Didascaliae et Per. in Terentium      6
# Annius Florus                         5
# Hyginus Gromaticus                    5
# Cornelius Tacitus                     5
# Quintus Asconius Pedianus             5
#                                      ..
# Titus Annius Luscus                   1
# Antonius Panurgus                     1
# Q. Pompeius Q.f.A.n. Rufus            1
# Sentius Augurinus                     1
# Chalcidius                            1
# Gannius                               1
# Q. Aurelius Symmachus                 1
# Q. Caecilius Metellus Maced.          1
# Imperator Nero                        1
# Marcus Iunius Brutus [iur.]           1
# Priapea                               1
# Aufidius Bassus                       1
# Lucius Afranius                       1
# Luscius Lanuvinus                     1
# Cornificius Gallus                    1
# Gnaeus Matius                         1
# Marcus Iuventius Laterensis           1
# Anonymi Fragmenta de Iure Fisci       1
# Marcus Manilius                       1
# Q. Mucius Scaevola [pontifex]         1
# Carmen Evocationis                    1
# Publius Cornelius Dolabella           1
# Sextus Paconianus                     1
# Q. Caecilius Metellus Numid.          1
# Precatio Terrae                       1
# Appius Claudius Caecus                1
# Lucius Cornelius Sulla                1
# Publius Clodius Pulcher               1
# Zeno of Verona                        1
# Gaius Erucius                         1
# Name: Author, Length: 362, dtype: int64

# %%
author_df[author_df['Author']==author_df['Title']]
# Out:
#                            Author  PHI Author Number  \
# 12   Altercatio Hadr. et Epicteti               1500
# 137         Bucolica Einsidlensia                821
# 167                 Carmen Arvale                149
# 168             Carmen Devotionis                306
# 169            Carmen Evocationis                309
# 170    Carmen de Bello Aegyptiaco                706
# 284           Commentarii Augurum                492
# 285        Commentarii Consulares                494
# 455                  Laus Pisonis                911
# 501      Mimi Poetarum Incertorum                584
# 609      Precatio Omnium Herbarum                990
# 610               Precatio Terrae                993
# 611                       Priapea               1103
# 629                Sacra Argeorum                630
# 747             Tabulae Censoriae                658
# 831                Vita Iuvenalis               9969
#
#                             Title  PHI Work Number  Combined PHI Number  \
# 12   Altercatio Hadr. et Epicteti                1             1500.001
# 137         Bucolica Einsidlensia                1              821.001
# 167                 Carmen Arvale                1              149.001
# 168             Carmen Devotionis                1              306.001
# 169            Carmen Evocationis                1              309.001
# 170    Carmen de Bello Aegyptiaco                1              706.001
# 284           Commentarii Augurum                1              492.001
# 285        Commentarii Consulares                1              494.001
# 455                  Laus Pisonis                1              911.001
# 501      Mimi Poetarum Incertorum                1              584.001
# 609      Precatio Omnium Herbarum                1              990.001
# 610               Precatio Terrae                1              993.001
# 611                       Priapea                1             1103.001
# 629                Sacra Argeorum                1              630.001
# 747             Tabulae Censoriae                1              658.001
# 831                Vita Iuvenalis                1             9969.001
#
#                                      Reference Edition  \
# 12   Altercatio Hadriani Augusti et Epicteti Philos...
# 137  Calpurnii et Nemesiani Bucolica, Accedunt Eins...
# 167  Anthologia Latina sive Poesis Latinae Suppleme...
# 168  Ambrosii Theodosii Macrobii Saturnalia, ed. J....
# 169  Ambrosii Theodosii Macrobii Saturnalia, ed. J....
# 170  C. Rabirius, Bellum Actiacum e Papiro Herculan...
# 284  M. Terenti Varronis De Linguae Latinae Quae Su...
# 285  M. Terenti Varronis De Linguae Latinae Quae Su...
# 455  Laus Pisonis: Text, Übersetzung, Kommentar: In...
# 501                I Mimi Romani, ed. M. Bonaria, 1965
# 609  Anthologia Latina. Part 1, Vol. 1, ed. A. Ries...
# 610  Anthologia Latina. Part 1, Fasc. 1, ed. A. Rie...
# 611  Poetae Latini Minores. Vol. 2, Fasc. 2, ed. F....
# 629  M. Terenti Varronis De Linguae Latinae Quae Su...
# 747  M. Terenti Varronis De Linguae Latinae Quae Su...
# 831  A. Persi Flacci et D. Iuni Iuvenalis Saturae, ...
#
#                                        URL Publisher    Rights
# 12   http://latin.packhum.org/loc/1500/1/0       PHI  Fair Use
# 137   http://latin.packhum.org/loc/821/1/0       PHI  Fair Use
# 167   http://latin.packhum.org/loc/149/1/0       PHI  Fair Use
# 168   http://latin.packhum.org/loc/306/1/0       PHI  Fair Use
# 169   http://latin.packhum.org/loc/309/1/0       PHI  Fair Use
# 170   http://latin.packhum.org/loc/706/1/0       PHI  Fair Use
# 284   http://latin.packhum.org/loc/492/1/0       PHI  Fair Use
# 285   http://latin.packhum.org/loc/494/1/0       PHI  Fair Use
# 455   http://latin.packhum.org/loc/911/1/0       PHI  Fair Use
# 501   http://latin.packhum.org/loc/584/1/0       PHI  Fair Use
# 609   http://latin.packhum.org/loc/990/1/0       PHI  Fair Use
# 610   http://latin.packhum.org/loc/993/1/0       PHI  Fair Use
# 611  http://latin.packhum.org/loc/1103/1/0       PHI  Fair Use
# 629   http://latin.packhum.org/loc/630/1/0       PHI  Fair Use
# 747   http://latin.packhum.org/loc/658/1/0       PHI  Fair Use
# 831  http://latin.packhum.org/loc/9969/1/0       PHI  Fair Use

# %%
url = author_df[author_df['Author']=='Publius Vergilius Maro']['URL'].values[0]
driver.get(url)
